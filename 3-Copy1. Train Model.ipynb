# %%
import scipy.io as io
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import torch
from torch.optim import lr_scheduler
from util.misc import AverageMeter
from util.misc import mkdirs, to_device
from util.visualize import visualize_network_output
from util.summary import LogSummary
from datetime import datetime
import time

# datasets
from dataset.data_util import pil_load_img
from dataset.dataload import TextInstance, TextDataset
import torch.utils.data as data
from dataset.total_text import TotalText
from dataset.synth_text import SynthText
from util.config import config as cfg, update_config, print_config

# models
from models import TextNet

# Losses
from loss import TextLoss

# %%
# 学習の設定
dataset = "total-text"
LoadWeights = True
original = True # 論文と同等のネットワークか
resnet = False
batch_size = 4
train_step = 0

# define backbone_name for model save+load
if original:
    backbone_name = "vgg16-original"
else:
    backbone_name = "vgg16"
if resnet:
    backbone_name = "resnet50"

# Load path
WeightPath = "weights/synthtext/textsnake_{}_0.pth".format(backbone_name)

# %%
# logger
log_dir = os.path.join(cfg.log_dir, datetime.now().strftime('%b%d_%H-%M-%S_') + cfg.exp_name)
logger = LogSummary(log_dir)

# %%
# Define model
if resnet:
    model = TextNet(original=original, backbone="resnet50")
else:
    model = TextNet(original=original)

# Cuda?
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device=="cuda":
    cudnn.benchmark = True
model.to(device)

# Load weights if required
if LoadWeights:
    model.load_state_dict(torch.load(WeightPath)['model'])

# %%
# Data augumentationの設定。
"""
Images are randomly rotated, and cropped with areas ranging from 0.24 to 1.69
and aspect ratios ranging from 0.33 to 3. After that, noise, blur, and lightness
are randomly adjusted. We ensure that the text on the augmented images are
still legible, if they are legible before augmentation.

→ crop areaの設定を論文に忠実になるように変更
"""
from util.augmentation import BaseTransform, Augmentation
# 論文の通りrandom resize scale(0.24~1.69) aspect(0.33~3)、Mirror flip,, random rotation, 
# lighting noiseを付加

# %%
# Define dataset
# 最初にSynthTextで1 epoch学習し、その重みを元にTotalTextでFinetuneする。
if dataset == 'total-text':
    # Train with augumentations.
    trainset = TotalText(
        data_root='data/total-text',
        ignore_list=None,
        is_training=True,
        transform=Augmentation(size=cfg.input_size, mean=cfg.means, std=cfg.stds)
    )
    # Validation時にはaugumentationはせず、normalizeとresizeのみ。
    valset = TotalText(
        data_root='data/total-text',
        ignore_list=None,
        is_training=False,
        transform=BaseTransform(size=cfg.input_size, mean=cfg.means, std=cfg.stds)
    )
    
elif dataset == 'synth-text':
    # Synthtextはtrainingのみ.
    trainset = SynthText(
        data_root='data/SynthText',
        is_training=True,
        transform=Augmentation(size=cfg.input_size, mean=cfg.means, std=cfg.stds)
    )
    valset = None
    
else:
    raise NotImplementedError(dataset)
    
# Define loaders
train_loader = torch.utils.data.DataLoader(trainset,batch_size=batch_size,shuffle=True, num_workers=8)
if dataset == "total-text":
    val_loader = torch.utils.data.DataLoader(valset,batch_size=batch_size, num_workers=8)

# %% [markdown]
# 可視化してaugumentationが上手く適応できているか確認

# %%
for i in range(5):
    # show some images
    image, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map, meta = trainset[0]
    print("show imgs")
    plt.imshow(image.transpose([1,2,0]))
    plt.show()
    print("tcl_mask")
    plt.imshow(tcl_mask)
    plt.show()
    print("radius_map")
    plt.imshow(radius_map)
    plt.show()
    print("sin_map")
    plt.imshow(sin_map)
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# show imgs
# tcl_mask
# radius_map
# sin_map
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# show imgs
# tcl_mask
# radius_map
# sin_map
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# show imgs
# tcl_mask
# radius_map
# sin_map
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# show imgs
# tcl_mask
# radius_map
# sin_map
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# show imgs
# tcl_mask
# radius_map
# sin_map

# %% [markdown]
# # Define Loss and optimizer

# %%
# コード解説はloss.pyに記載
criterion = TextLoss()

# %%
"""
We adopt the Adam optimazer [41] as our learning rate scheme. During the pre-training stage,
the learning rate is fixed to 10−3. During the fine-tuning stage, the learing rate is
set to 10−3 initially and decaies with a rate of 0.8 every 5000 iterations.
"""
# AdamとStepLRschedulerを使用。
lr = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.8)

# %% [markdown]
# # Trainingを定義

# %%
# モデル保存の便利関数を流用
def save_model(model, epoch, lr, optimzer):
    save_dir = os.path.join(cfg.save_dir, cfg.exp_name)
    if not os.path.exists(save_dir):
        mkdirs(save_dir)

    save_path = os.path.join(save_dir, 'textsnake_{}_{}.pth'.format(backbone_name, epoch))
    print('Saving to {}.'.format(save_path))
    state_dict = {
        'lr': lr,
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimzer.state_dict()
    }
    torch.save(state_dict, save_path)

# %%
def train(model, train_loader, criterion, scheduler, optimizer, epoch, logger):
    global train_step
    losses = AverageMeter()
    batch_time = AverageMeter()
    data_time = AverageMeter()
    end = time.time()
    model.train()
    scheduler.step()
    
    print('Epoch: {} : LR = {}'.format(epoch, optimizer.state_dict()['param_groups'][0]['lr']))

    for i, (img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map, meta) in enumerate(train_loader):
        data_time.update(time.time() - end)

        train_step += 1
        # Cudaへ
        img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map = to_device(
            img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map)
        
        # 画像を入力しpredictionを元にロス計算
        output = model(img)
        tr_loss, tcl_loss, sin_loss, cos_loss, radii_loss = \
            criterion(output, tr_mask, tcl_mask, sin_map, cos_map, radius_map, train_mask)
        
        # 論文ではそれぞれのロスに重み付けをしていない
        # >The weights constants λ1, λ2, λ3, λ4 and λ5 are all set to 1 in our experiments.
        loss = tr_loss + tcl_loss + sin_loss + cos_loss + radii_loss

        # スケジューラを更新
        if dataset=="total-text":
            scheduler.step()
            
        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()    
        
        # トラッカー更新。便利なのでそのまま使った。
        losses.update(loss.item())
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if cfg.viz and i % cfg.viz_freq == 0:
            visualize_network_output(output, tr_mask, tcl_mask, mode='train')

        if i % cfg.display_freq == 0:
            print('({:d} / {:d}) - Loss: {:.4f} - tr_loss: {:.4f} - tcl_loss: {:.4f} - sin_loss: {:.4f} - cos_loss: {:.4f} - radii_loss: {:.4f}'.format(
                i, len(train_loader), loss.item(), tr_loss.item(), tcl_loss.item(), sin_loss.item(), cos_loss.item(), radii_loss.item())
            )

        if i % cfg.log_freq == 0:
            logger.write_scalars({
                'loss': loss.item(),
                'tr_loss': tr_loss.item(),
                'tcl_loss': tcl_loss.item(),
                'sin_loss': sin_loss.item(),
                'cos_loss': cos_loss.item(),
                'radii_loss': radii_loss.item()
            }, tag='train', n_iter=train_step)
            
        if dataset == "synth-text" and i%1000 == 0:
            save_model(model, epoch, scheduler.get_lr(), optimizer)
            
    if epoch % 10 == 0:
        save_model(model, epoch, scheduler.get_lr(), optimizer)

    print('Training Loss: {}'.format(losses.avg))

# %% [markdown]
# # Validationを定義。ほぼtrainと同様。

# %%
def validation(model, valid_loader, criterion, epoch, logger):
    # gradを計算しないことでメモリ節約、高速化
    with torch.no_grad():
        model.eval()
        losses = AverageMeter()
        tr_losses = AverageMeter()
        tcl_losses = AverageMeter()
        sin_losses = AverageMeter()
        cos_losses = AverageMeter()
        radii_losses = AverageMeter()

        for i, (img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map, meta) in enumerate(valid_loader):

            img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map = to_device(
                img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map)

            output = model(img)

            tr_loss, tcl_loss, sin_loss, cos_loss, radii_loss = \
                criterion(output, tr_mask, tcl_mask, sin_map, cos_map, radius_map, train_mask)
            loss = tr_loss + tcl_loss + sin_loss + cos_loss + radii_loss

            # update losses
            losses.update(loss.item())
            tr_losses.update(tr_loss.item())
            tcl_losses.update(tcl_loss.item())
            sin_losses.update(sin_loss.item())
            cos_losses.update(cos_loss.item())
            radii_losses.update(radii_loss.item())

            if cfg.viz and i % cfg.viz_freq == 0:
                visualize_network_output(output, tr_mask, tcl_mask, mode='val')

            if i % cfg.display_freq == 0:
                print(
                    'Validation: - Loss: {:.4f} - tr_loss: {:.4f} - tcl_loss: {:.4f} - sin_loss: {:.4f} - cos_loss: {:.4f} - radii_loss: {:.4f}'.format(
                        loss.item(), tr_loss.item(), tcl_loss.item(), sin_loss.item(),
                        cos_loss.item(), radii_loss.item())
                )

        logger.write_scalars({
            'loss': losses.avg,
            'tr_loss': tr_losses.avg,
            'tcl_loss': tcl_losses.avg,
            'sin_loss': sin_losses.avg,
            'cos_loss': cos_losses.avg,
            'radii_loss': radii_losses.avg
        }, tag='val', n_iter=epoch)

        print('Validation Loss: {}'.format(losses.avg))

# %% [markdown]
# # 学習ループ開始

# %%
print('Start training TextSnake.')
import warnings
import gc
warnings.simplefilter('ignore')

if dataset == "synth-text":
    end_epoch=1
else:
    end_epoch =  cfg.max_epoch

for epoch in range(cfg.start_epoch, end_epoch):
    train(model, train_loader, criterion, scheduler, optimizer, epoch, logger)
    if valset:
        validation(model, val_loader, criterion, epoch, logger)
    # ループ後にメモリ解放
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# Start training TextSnake.
# Epoch: 0 : LR = 0.001
# (0 / 314) - Loss: 2.0015 - tr_loss: 0.5105 - tcl_loss: 0.4811 - sin_loss: 0.0380 - cos_loss: 0.0878 - radii_loss: 0.8842
# (100 / 314) - Loss: 1.5891 - tr_loss: 0.3398 - tcl_loss: 0.4458 - sin_loss: 0.0890 - cos_loss: 0.0867 - radii_loss: 0.6279
# (200 / 314) - Loss: 2.2047 - tr_loss: 0.5421 - tcl_loss: 0.4604 - sin_loss: 0.0554 - cos_loss: 0.0949 - radii_loss: 1.0520
# (300 / 314) - Loss: 1.3861 - tr_loss: 0.4445 - tcl_loss: 0.4186 - sin_loss: 0.0501 - cos_loss: 0.0760 - radii_loss: 0.3969
# Saving to weights/totaltext/textsnake_vgg16-original_0.pth.
# Training Loss: 1.835676755495132
# Validation: - Loss: 1.2255 - tr_loss: 0.3613 - tcl_loss: 0.4240 - sin_loss: 0.0692 - cos_loss: 0.0831 - radii_loss: 0.2879
# Validation Loss: 1.4239749813079834
# Epoch: 1 : LR = 0.001
# (0 / 314) - Loss: 1.2767 - tr_loss: 0.4674 - tcl_loss: 0.4464 - sin_loss: 0.0507 - cos_loss: 0.0650 - radii_loss: 0.2472
# (100 / 314) - Loss: 1.3038 - tr_loss: 0.3610 - tcl_loss: 0.4195 - sin_loss: 0.0376 - cos_loss: 0.0973 - radii_loss: 0.3884
# (200 / 314) - Loss: 1.6202 - tr_loss: 0.4371 - tcl_loss: 0.5202 - sin_loss: 0.0882 - cos_loss: 0.2242 - radii_loss: 0.3505
# (300 / 314) - Loss: 1.6903 - tr_loss: 0.4245 - tcl_loss: 0.4347 - sin_loss: 0.0842 - cos_loss: 0.0642 - radii_loss: 0.6827
# Training Loss: 1.819026349456447
# Validation: - Loss: 1.8219 - tr_loss: 0.3788 - tcl_loss: 0.4400 - sin_loss: 0.0489 - cos_loss: 0.0849 - radii_loss: 0.8693
# Validation Loss: 1.7585149002075195
# Epoch: 2 : LR = 0.001
# (0 / 314) - Loss: 1.6024 - tr_loss: 0.3490 - tcl_loss: 0.4534 - sin_loss: 0.0566 - cos_loss: 0.0788 - radii_loss: 0.6646
# (100 / 314) - Loss: 1.8889 - tr_loss: 0.4553 - tcl_loss: 0.4952 - sin_loss: 0.1395 - cos_loss: 0.1279 - radii_loss: 0.6710
# (200 / 314) - Loss: 1.8848 - tr_loss: 0.4986 - tcl_loss: 0.4825 - sin_loss: 0.2408 - cos_loss: 0.1842 - radii_loss: 0.4787
# (300 / 314) - Loss: 2.6318 - tr_loss: 0.5856 - tcl_loss: 0.5625 - sin_loss: 0.1702 - cos_loss: 0.0845 - radii_loss: 1.2290
# Training Loss: 1.8263931293396434
# Validation: - Loss: 2.0199 - tr_loss: 0.3724 - tcl_loss: 0.4399 - sin_loss: 0.0530 - cos_loss: 0.0846 - radii_loss: 1.0701
# Validation Loss: 2.0750536727905273
# Epoch: 3 : LR = 0.001
# (0 / 314) - Loss: 1.6058 - tr_loss: 0.4285 - tcl_loss: 0.4679 - sin_loss: 0.0601 - cos_loss: 0.0191 - radii_loss: 0.6302
# (100 / 314) - Loss: 2.1026 - tr_loss: 0.7710 - tcl_loss: 0.4425 - sin_loss: 0.1944 - cos_loss: 0.0665 - radii_loss: 0.6283
# (200 / 314) - Loss: 1.4959 - tr_loss: 0.3596 - tcl_loss: 0.4281 - sin_loss: 0.0516 - cos_loss: 0.0391 - radii_loss: 0.6175
# (300 / 314) - Loss: 1.6753 - tr_loss: 0.5607 - tcl_loss: 0.5196 - sin_loss: 0.0983 - cos_loss: 0.1871 - radii_loss: 0.3097
# Training Loss: 1.8112839061743136
# Validation: - Loss: 2.1539 - tr_loss: 0.4377 - tcl_loss: 0.4518 - sin_loss: 0.0913 - cos_loss: 0.0822 - radii_loss: 1.0910
# Validation Loss: 2.1608612600962323
# Epoch: 4 : LR = 0.001
# (0 / 314) - Loss: 1.7046 - tr_loss: 0.5033 - tcl_loss: 0.4842 - sin_loss: 0.1260 - cos_loss: 0.2107 - radii_loss: 0.3803
# (100 / 314) - Loss: 1.6684 - tr_loss: 0.3674 - tcl_loss: 0.4669 - sin_loss: 0.0559 - cos_loss: 0.0221 - radii_loss: 0.7560
# (200 / 314) - Loss: 2.0456 - tr_loss: 0.5552 - tcl_loss: 0.5012 - sin_loss: 0.0526 - cos_loss: 0.0528 - radii_loss: 0.8838
# (300 / 314) - Loss: 1.8259 - tr_loss: 0.4814 - tcl_loss: 0.4599 - sin_loss: 0.1243 - cos_loss: 0.0554 - radii_loss: 0.7049
# Training Loss: 1.8334711171259546
# Validation: - Loss: 2.0349 - tr_loss: 0.4048 - tcl_loss: 0.4330 - sin_loss: 0.0489 - cos_loss: 0.0836 - radii_loss: 1.0645
# Validation Loss: 2.074862740834554
# Epoch: 5 : LR = 0.001
# (0 / 314) - Loss: 2.6522 - tr_loss: 0.6309 - tcl_loss: 0.5026 - sin_loss: 0.0958 - cos_loss: 0.0974 - radii_loss: 1.3255
# (100 / 314) - Loss: 1.5939 - tr_loss: 0.5160 - tcl_loss: 0.5219 - sin_loss: 0.1040 - cos_loss: 0.0544 - radii_loss: 0.3977
# (200 / 314) - Loss: 1.5952 - tr_loss: 0.5156 - tcl_loss: 0.4886 - sin_loss: 0.1204 - cos_loss: 0.1200 - radii_loss: 0.3507
# (300 / 314) - Loss: 2.0910 - tr_loss: 0.4490 - tcl_loss: 0.5419 - sin_loss: 0.0589 - cos_loss: 0.1191 - radii_loss: 0.9222
# Training Loss: 1.8445573414966558
# Validation: - Loss: 2.1715 - tr_loss: 0.4102 - tcl_loss: 0.4450 - sin_loss: 0.0881 - cos_loss: 0.0847 - radii_loss: 1.1435
# Validation Loss: 2.1268812624613442
# Epoch: 6 : LR = 0.001
# (0 / 314) - Loss: 2.1666 - tr_loss: 0.4826 - tcl_loss: 0.5837 - sin_loss: 0.1072 - cos_loss: 0.0798 - radii_loss: 0.9133
# (100 / 314) - Loss: 1.3619 - tr_loss: 0.4580 - tcl_loss: 0.5401 - sin_loss: 0.1544 - cos_loss: 0.0830 - radii_loss: 0.1263
# (200 / 314) - Loss: 1.7689 - tr_loss: 0.4379 - tcl_loss: 0.4472 - sin_loss: 0.0480 - cos_loss: 0.0626 - radii_loss: 0.7733
# (300 / 314) - Loss: 1.4805 - tr_loss: 0.5643 - tcl_loss: 0.5103 - sin_loss: 0.0956 - cos_loss: 0.0551 - radii_loss: 0.2551
# Training Loss: 1.8213026432474708
# Validation: - Loss: 2.0191 - tr_loss: 0.4032 - tcl_loss: 0.4421 - sin_loss: 0.0574 - cos_loss: 0.0838 - radii_loss: 1.0325
# Validation Loss: 2.072304204305013
# Epoch: 7 : LR = 0.001
# (0 / 314) - Loss: 1.5592 - tr_loss: 0.4157 - tcl_loss: 0.4708 - sin_loss: 0.1148 - cos_loss: 0.1336 - radii_loss: 0.4243
# (100 / 314) - Loss: 1.7145 - tr_loss: 0.5118 - tcl_loss: 0.4480 - sin_loss: 0.0350 - cos_loss: 0.0367 - radii_loss: 0.6829
# (200 / 314) - Loss: 2.3209 - tr_loss: 0.4892 - tcl_loss: 0.5619 - sin_loss: 0.1410 - cos_loss: 0.1672 - radii_loss: 0.9616
# (300 / 314) - Loss: 1.6381 - tr_loss: 0.4680 - tcl_loss: 0.4780 - sin_loss: 0.0957 - cos_loss: 0.1714 - radii_loss: 0.4251
# Training Loss: 1.8069909374425366
# Validation: - Loss: 2.0705 - tr_loss: 0.3850 - tcl_loss: 0.4323 - sin_loss: 0.0457 - cos_loss: 0.0854 - radii_loss: 1.1222
# Validation Loss: 2.078118383089701
# Epoch: 8 : LR = 0.0008
# (0 / 314) - Loss: 1.8407 - tr_loss: 0.5377 - tcl_loss: 0.4634 - sin_loss: 0.0928 - cos_loss: 0.1572 - radii_loss: 0.5897
# (100 / 314) - Loss: 1.7564 - tr_loss: 0.4548 - tcl_loss: 0.4351 - sin_loss: 0.0384 - cos_loss: 0.0551 - radii_loss: 0.7731
# (200 / 314) - Loss: 1.9914 - tr_loss: 0.5675 - tcl_loss: 0.5435 - sin_loss: 0.0760 - cos_loss: 0.2778 - radii_loss: 0.5267
# (300 / 314) - Loss: 1.9855 - tr_loss: 0.4922 - tcl_loss: 0.5122 - sin_loss: 0.0859 - cos_loss: 0.1426 - radii_loss: 0.7526
# Training Loss: 1.8085107347767824
# Validation: - Loss: 2.2618 - tr_loss: 0.4076 - tcl_loss: 0.4529 - sin_loss: 0.0628 - cos_loss: 0.0851 - radii_loss: 1.2535
# Validation Loss: 2.1868203624089557
# Epoch: 9 : LR = 0.0008
# (0 / 314) - Loss: 2.3962 - tr_loss: 0.4788 - tcl_loss: 0.4728 - sin_loss: 0.0477 - cos_loss: 0.0476 - radii_loss: 1.3492
# (100 / 314) - Loss: 1.2227 - tr_loss: 0.3735 - tcl_loss: 0.4319 - sin_loss: 0.0422 - cos_loss: 0.1085 - radii_loss: 0.2666
# (200 / 314) - Loss: 2.0828 - tr_loss: 0.5142 - tcl_loss: 0.4146 - sin_loss: 0.0900 - cos_loss: 0.1181 - radii_loss: 0.9458
# (300 / 314) - Loss: 1.8731 - tr_loss: 0.4332 - tcl_loss: 0.4175 - sin_loss: 0.0342 - cos_loss: 0.0697 - radii_loss: 0.9184
# Training Loss: 1.8446914401783305
# Validation: - Loss: 1.9881 - tr_loss: 0.3983 - tcl_loss: 0.4471 - sin_loss: 0.0562 - cos_loss: 0.0869 - radii_loss: 0.9996
# Validation Loss: 1.9954503456751504
# Epoch: 10 : LR = 0.0008
# (0 / 314) - Loss: 1.9786 - tr_loss: 0.5040 - tcl_loss: 0.4848 - sin_loss: 0.0874 - cos_loss: 0.1722 - radii_loss: 0.7302
# (100 / 314) - Loss: 1.8099 - tr_loss: 0.5940 - tcl_loss: 0.5077 - sin_loss: 0.0642 - cos_loss: 0.0784 - radii_loss: 0.5657
# (200 / 314) - Loss: 1.7950 - tr_loss: 0.4997 - tcl_loss: 0.4522 - sin_loss: 0.0531 - cos_loss: 0.1512 - radii_loss: 0.6389
# (300 / 314) - Loss: 1.4393 - tr_loss: 0.4298 - tcl_loss: 0.5164 - sin_loss: 0.0871 - cos_loss: 0.2227 - radii_loss: 0.1832
# Saving to weights/totaltext/textsnake_vgg16-original_10.pth.
# Training Loss: 1.7937157617253103
# Validation: - Loss: 2.2084 - tr_loss: 0.4195 - tcl_loss: 0.4367 - sin_loss: 0.0725 - cos_loss: 0.0858 - radii_loss: 1.1938
# Validation Loss: 2.169199999173482
# Epoch: 11 : LR = 0.0008
# (0 / 314) - Loss: 1.2320 - tr_loss: 0.3492 - tcl_loss: 0.4863 - sin_loss: 0.0865 - cos_loss: 0.0691 - radii_loss: 0.2410
# (100 / 314) - Loss: 1.6725 - tr_loss: 0.3971 - tcl_loss: 0.3996 - sin_loss: 0.0402 - cos_loss: 0.0514 - radii_loss: 0.7842
# (200 / 314) - Loss: 1.8265 - tr_loss: 0.4710 - tcl_loss: 0.4921 - sin_loss: 0.0934 - cos_loss: 0.1855 - radii_loss: 0.5844
# (300 / 314) - Loss: 1.6633 - tr_loss: 0.5547 - tcl_loss: 0.5076 - sin_loss: 0.0805 - cos_loss: 0.0952 - radii_loss: 0.4252
# Training Loss: 1.8296986772755908
# Validation: - Loss: 1.8833 - tr_loss: 0.3767 - tcl_loss: 0.4260 - sin_loss: 0.0569 - cos_loss: 0.0856 - radii_loss: 0.9382
# Validation Loss: 1.866436816851298
# Epoch: 12 : LR = 0.0008
# (0 / 314) - Loss: 1.9929 - tr_loss: 0.8720 - tcl_loss: 0.4585 - sin_loss: 0.0507 - cos_loss: 0.1483 - radii_loss: 0.4633
# (100 / 314) - Loss: 1.5474 - tr_loss: 0.3727 - tcl_loss: 0.4652 - sin_loss: 0.0324 - cos_loss: 0.2009 - radii_loss: 0.4763
# (200 / 314) - Loss: 1.7231 - tr_loss: 0.3306 - tcl_loss: 0.4633 - sin_loss: 0.0661 - cos_loss: 0.1380 - radii_loss: 0.7250
# (300 / 314) - Loss: 1.6061 - tr_loss: 0.4230 - tcl_loss: 0.4720 - sin_loss: 0.0748 - cos_loss: 0.0280 - radii_loss: 0.6083
# Training Loss: 1.8292793027914254
# Validation: - Loss: 2.0088 - tr_loss: 0.3800 - tcl_loss: 0.4314 - sin_loss: 0.0560 - cos_loss: 0.0852 - radii_loss: 1.0562
# Validation Loss: 2.015314439137777
# Epoch: 13 : LR = 0.0008
# (0 / 314) - Loss: 1.5549 - tr_loss: 0.4450 - tcl_loss: 0.5089 - sin_loss: 0.0569 - cos_loss: 0.0923 - radii_loss: 0.4519
# (100 / 314) - Loss: 1.6491 - tr_loss: 0.4124 - tcl_loss: 0.4202 - sin_loss: 0.0527 - cos_loss: 0.0257 - radii_loss: 0.7381
# (200 / 314) - Loss: 1.7095 - tr_loss: 0.4118 - tcl_loss: 0.4092 - sin_loss: 0.0583 - cos_loss: 0.0989 - radii_loss: 0.7312
# (300 / 314) - Loss: 1.8021 - tr_loss: 0.6097 - tcl_loss: 0.4050 - sin_loss: 0.0377 - cos_loss: 0.1175 - radii_loss: 0.6322
# Training Loss: 1.798983378015506
# Validation: - Loss: 1.8884 - tr_loss: 0.3838 - tcl_loss: 0.4350 - sin_loss: 0.0529 - cos_loss: 0.0867 - radii_loss: 0.9300
# Validation Loss: 1.9483688497543334
# Epoch: 14 : LR = 0.0008
# (0 / 314) - Loss: 1.6589 - tr_loss: 0.4000 - tcl_loss: 0.4649 - sin_loss: 0.0696 - cos_loss: 0.0977 - radii_loss: 0.6267
# (100 / 314) - Loss: 1.2913 - tr_loss: 0.3671 - tcl_loss: 0.4503 - sin_loss: 0.0496 - cos_loss: 0.0536 - radii_loss: 0.3706
# (200 / 314) - Loss: 1.7717 - tr_loss: 0.4347 - tcl_loss: 0.5388 - sin_loss: 0.0625 - cos_loss: 0.1530 - radii_loss: 0.5826
# (300 / 314) - Loss: 1.6605 - tr_loss: 0.4888 - tcl_loss: 0.4530 - sin_loss: 0.0413 - cos_loss: 0.0687 - radii_loss: 0.6088
# Training Loss: 1.8098408940491404
# Validation: - Loss: 1.6650 - tr_loss: 0.3961 - tcl_loss: 0.4384 - sin_loss: 0.0552 - cos_loss: 0.0833 - radii_loss: 0.6919
# Validation Loss: 1.7844878021876018
# Epoch: 15 : LR = 0.0008
# (0 / 314) - Loss: 1.6299 - tr_loss: 0.3898 - tcl_loss: 0.4470 - sin_loss: 0.0352 - cos_loss: 0.0497 - radii_loss: 0.7082
# (100 / 314) - Loss: 1.7196 - tr_loss: 0.3478 - tcl_loss: 0.4634 - sin_loss: 0.0625 - cos_loss: 0.0456 - radii_loss: 0.8004
# (200 / 314) - Loss: 1.6145 - tr_loss: 0.5034 - tcl_loss: 0.4929 - sin_loss: 0.0758 - cos_loss: 0.0916 - radii_loss: 0.4507
# (300 / 314) - Loss: 1.6894 - tr_loss: 0.3490 - tcl_loss: 0.3838 - sin_loss: 0.0539 - cos_loss: 0.1211 - radii_loss: 0.7817
# Training Loss: 1.8098501118884724
# Validation: - Loss: 1.6460 - tr_loss: 0.3762 - tcl_loss: 0.4292 - sin_loss: 0.0508 - cos_loss: 0.0828 - radii_loss: 0.7069
# Validation Loss: 1.7007483037312825
# Epoch: 16 : LR = 0.0006400000000000002
# (0 / 314) - Loss: 1.3382 - tr_loss: 0.3346 - tcl_loss: 0.4246 - sin_loss: 0.0510 - cos_loss: 0.0949 - radii_loss: 0.4331
# (100 / 314) - Loss: 2.2160 - tr_loss: 0.6123 - tcl_loss: 0.5922 - sin_loss: 0.1243 - cos_loss: 0.0093 - radii_loss: 0.8779
# (200 / 314) - Loss: 1.5646 - tr_loss: 0.3876 - tcl_loss: 0.4804 - sin_loss: 0.0515 - cos_loss: 0.1006 - radii_loss: 0.5445
# (300 / 314) - Loss: 1.9330 - tr_loss: 0.5076 - tcl_loss: 0.5201 - sin_loss: 0.0420 - cos_loss: 0.2311 - radii_loss: 0.6322
# Training Loss: 1.7776869444330787
# Validation: - Loss: 1.9437 - tr_loss: 0.3705 - tcl_loss: 0.4325 - sin_loss: 0.0563 - cos_loss: 0.0844 - radii_loss: 1.0000
# Validation Loss: 2.0049543380737305
# Epoch: 17 : LR = 0.0006400000000000002
# (0 / 314) - Loss: 1.6422 - tr_loss: 0.3835 - tcl_loss: 0.4138 - sin_loss: 0.0401 - cos_loss: 0.1010 - radii_loss: 0.7038
# (100 / 314) - Loss: 1.9472 - tr_loss: 0.4274 - tcl_loss: 0.4540 - sin_loss: 0.0451 - cos_loss: 0.2031 - radii_loss: 0.8176
# (200 / 314) - Loss: 1.5636 - tr_loss: 0.4581 - tcl_loss: 0.5656 - sin_loss: 0.1032 - cos_loss: 0.0293 - radii_loss: 0.4073
# (300 / 314) - Loss: 1.7838 - tr_loss: 0.4898 - tcl_loss: 0.4350 - sin_loss: 0.0580 - cos_loss: 0.0949 - radii_loss: 0.7060
# Training Loss: 1.770133036337081
# Validation: - Loss: 1.4452 - tr_loss: 0.3803 - tcl_loss: 0.4231 - sin_loss: 0.0501 - cos_loss: 0.0817 - radii_loss: 0.5101

# %%
model
